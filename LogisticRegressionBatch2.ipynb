# %% [markdown]
# ### Load  Basic Libraries

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset("iris")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
data1=data[data["species"]!="setosa"]

# %%
data1.head(2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor

# %%
data1["species"].unique()
# Out:
# array(['versicolor', 'virginica'], dtype=object)

# %%
data1["species"]=data1["species"].map({"versicolor":0,"virginica":1})
# Out:
# C:\Users\shikha choudhary\AppData\Local\Temp\ipykernel_15992\3394530424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["species"]=data1["species"].map({"versicolor":0,"virginica":1})

# %%
data1["species"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data1.head(2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 50           7.0          3.2           4.7          1.4        0
# 51           6.4          3.2           4.5          1.5        0

# %% [markdown]
# ### Data division part

# %%
x=data1.iloc[:,:-1]      # -1-1=-2
y=data1.iloc[:,-1]

# %%
x.head(2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 50           7.0          3.2           4.7          1.4
# 51           6.4          3.2           4.5          1.5

# %%
y.head()
# Out:
# 50    0
# 51    0
# 52    0
# 53    0
# 54    0
# Name: species, dtype: int64

# %% [markdown]
# ### Data Splition in Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=42)

# %%
x_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 65            6.7          3.1           4.4          1.4
# 90            5.5          2.6           4.4          1.2
# 146           6.3          2.5           5.0          1.9
# 59            5.2          2.7           3.9          1.4
# 122           7.7          2.8           6.7          2.0

# %%
y_train.head()
# Out:
# 65     0
# 90     0
# 146    1
# 59     0
# 122    1
# Name: species, dtype: int64

# %% [markdown]
# ### Model Building part

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model=LogisticRegression()

# %%
logistic_model.fit(x_train,y_train)    ## 1/1+e^-z  , z=[m1x1+m2x2+m3x3+m4x4]+C    , z=x1+2x2+2.5x3+3x4+10
# Out:
# LogisticRegression()
